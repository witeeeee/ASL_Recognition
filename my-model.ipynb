# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras import utils, callbacks
from keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from keras.models import Sequential, Model, load_model
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization, Add, Input, ZeroPadding2D, AveragePooling2D,GlobalAveragePooling2D
from keras.initializers import glorot_uniform
from keras.layers import concatenate
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import cv2
from glob import glob
from numpy import floor
import numpy as np
import random
from numpy.random import seed
seed(1)

# %%
def plot_three_samples(letter):
    print("ASL Alphabet for letter: "+letter)
    base_path = '../asl_alphabet_train/asl_alphabet_train/'
    img_path = base_path + letter + '/**'
    path_contents = glob(img_path)
    
    plt.figure(figsize=(16,16))
    imgs = random.sample(path_contents,3)
    plt.subplot(1,3,1)
    plt.imshow(cv2.imread(imgs[0]))
    plt.subplot(1,3,2)
    plt.imshow(cv2.imread(imgs[1]))
    plt.subplot(1,3,3)
    plt.imshow(cv2.imread(imgs[2]))
    
    return

plot_three_samples('S')
# Out:
# ASL Alphabet for letter: S

# %%
import pandas as pd
from pathlib import Path
import os.path
dir_ = Path('../asl_alphabet_train')
file_paths = list(dir_.glob(r'**/*.jpg'))

# %%
def proc_img(filepath):
    """ Create a DataFrame with the filepath and the labels of the pictures
    """

    labels = [str(filepath[i]).split("\\")[-2] \
              for i in range(len(filepath))]

    filepath = pd.Series(filepath, name='Filepath').astype(str)
    labels = pd.Series(labels, name='Label')

    # Concatenate filepaths and labels
    df = pd.concat([filepath, labels], axis=1)

    # Shuffle the DataFrame and reset index
    df = df.sample(frac=1,random_state=0).reset_index(drop = True)
    
    return df

df = proc_img(file_paths)

print(f'Number of pictures in the dataset: {df.shape[0]}\n')
print(f'Number of different labels: {len(df.Label.unique())}\n')
print(f'Labels: {df.Label.unique()}')

# The DataFrame with the filepaths in one column and the labels in the other one
df.head(5)
# Out:
# Number of pictures in the dataset: 87000
#
# Number of different labels: 29
#
# Labels: ['W' 'E' 'O' 'K' 'N' 'C' 'L' 'del' 'G' 'H' 'U' 'Z' 'Y' 'M' 'nothing' 'P'
#  'T' 'R' 'V' 'J' 'A' 'F' 'D' 'X' 'B' 'Q' 'space' 'S' 'I']
#                                             Filepath Label
# 0  ..\asl_alphabet_train\asl_alphabet_train\W\W27...     W
# 1  ..\asl_alphabet_train\asl_alphabet_train\E\E27...     E
# 2  ..\asl_alphabet_train\asl_alphabet_train\O\O13...     O
# 3  ..\asl_alphabet_train\asl_alphabet_train\K\K86...     K
# 4  ..\asl_alphabet_train\asl_alphabet_train\N\N39...     N

# %%
fig, axes = plt.subplots(nrows=4, ncols=6, figsize=(15, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(df.Filepath[i]))
    ax.set_title(df.Label[i], fontsize = 15)
plt.tight_layout(pad=0.5)
plt.show()

# %%
train_df, test_df = train_test_split(df, test_size=0.1, random_state=0)

# %%
target_size = (64,64)
target_dims = (64,64,3)
val_frac = 0.1
n_classes = 29
batch_size = 64

image_generator = ImageDataGenerator(samplewise_center = True, samplewise_std_normalization = True, validation_split=val_frac)

train_gen = image_generator.flow_from_dataframe(dataframe=train_df, target_size=target_size, x_col = 'Filepath', y_col = 'Label',
                                    class_mode = 'categorical',batch_size=batch_size, shuffle=True, subset='training')

val_gen = image_generator.flow_from_dataframe(dataframe=train_df, target_size=target_size, x_col='Filepath',
        y_col='Label',shuffle=True, subset='validation')

test_gen = image_generator.flow_from_dataframe(dataframe=test_df, x_col='Filepath',
        y_col='Label', target_size=target_size, shuffle=False)
# Out:
# Found 70470 validated image filenames belonging to 29 classes.
# Found 7830 validated image filenames belonging to 29 classes.
# Found 8700 validated image filenames belonging to 29 classes.

# %%
def res_block(X, filter, stage):

  # Convolutional_block
  X_copy = X

  f1 , f2, f3 = filter

  # Main Path
  X = Conv2D(f1, (1,1),strides = (1,1), name ='res_'+str(stage)+'_conv_a', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = MaxPooling2D((2,2), padding='same')(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_a')(X)
  X = Activation('relu')(X) 

  X = Conv2D(f2, kernel_size = (3,3), strides =(1,1), padding = 'same', name ='res_'+str(stage)+'_conv_b', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_b')(X)
  X = Activation('relu')(X) 

  X = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_conv_c', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_c')(X)


  # Short path
  X_copy = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_conv_copy', kernel_initializer= glorot_uniform(seed = 0))(X_copy)
  X_copy = MaxPooling2D((2,2), padding='same')(X_copy)
  X_copy = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_copy')(X_copy)

  # ADD
  X = Add()([X,X_copy])
  X = Activation('relu')(X)

  # Identity Block 1
  X_copy = X


  # Main Path
  X = Conv2D(f1, (1,1),strides = (1,1), name ='res_'+str(stage)+'_identity_1_a', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_a')(X)
  X = Activation('relu')(X) 

  X = Conv2D(f2, kernel_size = (3,3), strides =(1,1), padding = 'same', name ='res_'+str(stage)+'_identity_1_b', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_b')(X)
  X = Activation('relu')(X) 

  X = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_identity_1_c', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_c')(X)

  # ADD
  X = Add()([X,X_copy])
  X = Activation('relu')(X)

  # Identity Block 2
  X_copy = X


  # Main Path
  X = Conv2D(f1, (1,1),strides = (1,1), name ='res_'+str(stage)+'_identity_2_a', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_a')(X)
  X = Activation('relu')(X) 

  X = Conv2D(f2, kernel_size = (3,3), strides =(1,1), padding = 'same', name ='res_'+str(stage)+'_identity_2_b', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_b')(X)
  X = Activation('relu')(X) 

  X = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_identity_2_c', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_c')(X)

  # ADD
  X = Add()([X,X_copy])
  X = Activation('relu')(X)

  return X

# %%
input_shape = (64, 64, 3)

X_input = Input(input_shape)

# Zero-padding
X = ZeroPadding2D((3,3))(X_input)

# 1 - stage
X = Conv2D(64, (7,7), strides= (2,2), name = 'conv1', kernel_initializer= glorot_uniform(seed = 0))(X)
X = BatchNormalization(axis =3, name = 'bn_conv1')(X)
X = Activation('relu')(X)
X = MaxPooling2D((3,3), strides= (2,2), padding='same')(X)

# 2 - stage
X = res_block(X, filter= [64,64,256], stage= 2)

# 3 - stage
X = res_block(X, filter= [128,128,512], stage= 3)

# 4 - stage
X = res_block(X, filter= [256,256,1024], stage= 4)

# 5 - stage
X = res_block(X, filter= [512,512,2048], stage= 5)


# Average Pooling
X = AveragePooling2D((2,2), name = 'Averagea_Pooling', padding='same')(X)

# Final layer
X = Flatten()(X)
X = Dense(4096, activation = 'relu')(X)
X = Dropout(0.2)(X)
X = Dense(2048, activation = 'relu')(X)
X = Dropout(0.1)(X)
X = Dense(29, activation = 'softmax')(X)


my_model = Model( inputs= X_input, outputs = X)
my_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  zero_padding2d (ZeroPadding2D)  (None, 70, 70, 3)   0           ['input_1[0][0]']
#
#  conv1 (Conv2D)                 (None, 32, 32, 64)   9472        ['zero_padding2d[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 32, 32, 64)   256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 32, 32, 64)   0           ['bn_conv1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 16, 16, 64)   0           ['activation[0][0]']
#
#  res_2_conv_a (Conv2D)          (None, 16, 16, 64)   4160        ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 64)    0           ['res_2_conv_a[0][0]']
#
#  bn_2_conv_a (BatchNormalizatio  (None, 8, 8, 64)    256         ['max_pooling2d_1[0][0]']
#  n)
#
#  activation_1 (Activation)      (None, 8, 8, 64)     0           ['bn_2_conv_a[0][0]']
#
#  res_2_conv_b (Conv2D)          (None, 8, 8, 64)     36928       ['activation_1[0][0]']
#
#  bn_2_conv_b (BatchNormalizatio  (None, 8, 8, 64)    256         ['res_2_conv_b[0][0]']
#  n)
#
#  activation_2 (Activation)      (None, 8, 8, 64)     0           ['bn_2_conv_b[0][0]']
#
#  res_2_conv_copy (Conv2D)       (None, 16, 16, 256)  16640       ['max_pooling2d[0][0]']
#
#  res_2_conv_c (Conv2D)          (None, 8, 8, 256)    16640       ['activation_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 256)   0           ['res_2_conv_copy[0][0]']
#
#  bn_2_conv_c (BatchNormalizatio  (None, 8, 8, 256)   1024        ['res_2_conv_c[0][0]']
#  n)
#
#  bn_2_conv_copy (BatchNormaliza  (None, 8, 8, 256)   1024        ['max_pooling2d_2[0][0]']
#  tion)
#
#  add (Add)                      (None, 8, 8, 256)    0           ['bn_2_conv_c[0][0]',
#                                                                   'bn_2_conv_copy[0][0]']
#
#  activation_3 (Activation)      (None, 8, 8, 256)    0           ['add[0][0]']
#
#  res_2_identity_1_a (Conv2D)    (None, 8, 8, 64)     16448       ['activation_3[0][0]']
#
#  bn_2_identity_1_a (BatchNormal  (None, 8, 8, 64)    256         ['res_2_identity_1_a[0][0]']
#  ization)
#
#  activation_4 (Activation)      (None, 8, 8, 64)     0           ['bn_2_identity_1_a[0][0]']
#
#  res_2_identity_1_b (Conv2D)    (None, 8, 8, 64)     36928       ['activation_4[0][0]']
#
#  bn_2_identity_1_b (BatchNormal  (None, 8, 8, 64)    256         ['res_2_identity_1_b[0][0]']
#  ization)
#
#  activation_5 (Activation)      (None, 8, 8, 64)     0           ['bn_2_identity_1_b[0][0]']
#
#  res_2_identity_1_c (Conv2D)    (None, 8, 8, 256)    16640       ['activation_5[0][0]']
#
#  bn_2_identity_1_c (BatchNormal  (None, 8, 8, 256)   1024        ['res_2_identity_1_c[0][0]']
#  ization)
#
#  add_1 (Add)                    (None, 8, 8, 256)    0           ['bn_2_identity_1_c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 8, 8, 256)    0           ['add_1[0][0]']
#
#  res_2_identity_2_a (Conv2D)    (None, 8, 8, 64)     16448       ['activation_6[0][0]']
#
#  bn_2_identity_2_a (BatchNormal  (None, 8, 8, 64)    256         ['res_2_identity_2_a[0][0]']
#  ization)
#
#  activation_7 (Activation)      (None, 8, 8, 64)     0           ['bn_2_identity_2_a[0][0]']
#
#  res_2_identity_2_b (Conv2D)    (None, 8, 8, 64)     36928       ['activation_7[0][0]']
#
#  bn_2_identity_2_b (BatchNormal  (None, 8, 8, 64)    256         ['res_2_identity_2_b[0][0]']
#  ization)
#
#  activation_8 (Activation)      (None, 8, 8, 64)     0           ['bn_2_identity_2_b[0][0]']
#
#  res_2_identity_2_c (Conv2D)    (None, 8, 8, 256)    16640       ['activation_8[0][0]']
#
#  bn_2_identity_2_c (BatchNormal  (None, 8, 8, 256)   1024        ['res_2_identity_2_c[0][0]']
#  ization)
#
#  add_2 (Add)                    (None, 8, 8, 256)    0           ['bn_2_identity_2_c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 8, 8, 256)    0           ['add_2[0][0]']
#
#  res_3_conv_a (Conv2D)          (None, 8, 8, 128)    32896       ['activation_9[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 128)   0           ['res_3_conv_a[0][0]']
#
#  bn_3_conv_a (BatchNormalizatio  (None, 4, 4, 128)   512         ['max_pooling2d_3[0][0]']
#  n)
#
#  activation_10 (Activation)     (None, 4, 4, 128)    0           ['bn_3_conv_a[0][0]']
#
#  res_3_conv_b (Conv2D)          (None, 4, 4, 128)    147584      ['activation_10[0][0]']
#
#  bn_3_conv_b (BatchNormalizatio  (None, 4, 4, 128)   512         ['res_3_conv_b[0][0]']
#  n)
#
#  activation_11 (Activation)     (None, 4, 4, 128)    0           ['bn_3_conv_b[0][0]']
#
#  res_3_conv_copy (Conv2D)       (None, 8, 8, 512)    131584      ['activation_9[0][0]']
#
#  res_3_conv_c (Conv2D)          (None, 4, 4, 512)    66048       ['activation_11[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 512)   0           ['res_3_conv_copy[0][0]']
#
#  bn_3_conv_c (BatchNormalizatio  (None, 4, 4, 512)   2048        ['res_3_conv_c[0][0]']
#  n)
#
#  bn_3_conv_copy (BatchNormaliza  (None, 4, 4, 512)   2048        ['max_pooling2d_4[0][0]']
#  tion)
#
#  add_3 (Add)                    (None, 4, 4, 512)    0           ['bn_3_conv_c[0][0]',
#                                                                   'bn_3_conv_copy[0][0]']
#
#  activation_12 (Activation)     (None, 4, 4, 512)    0           ['add_3[0][0]']
#
#  res_3_identity_1_a (Conv2D)    (None, 4, 4, 128)    65664       ['activation_12[0][0]']
#
#  bn_3_identity_1_a (BatchNormal  (None, 4, 4, 128)   512         ['res_3_identity_1_a[0][0]']
#  ization)
#
#  activation_13 (Activation)     (None, 4, 4, 128)    0           ['bn_3_identity_1_a[0][0]']
#
#  res_3_identity_1_b (Conv2D)    (None, 4, 4, 128)    147584      ['activation_13[0][0]']
#
#  bn_3_identity_1_b (BatchNormal  (None, 4, 4, 128)   512         ['res_3_identity_1_b[0][0]']
#  ization)
#
#  activation_14 (Activation)     (None, 4, 4, 128)    0           ['bn_3_identity_1_b[0][0]']
#
#  res_3_identity_1_c (Conv2D)    (None, 4, 4, 512)    66048       ['activation_14[0][0]']
#
#  bn_3_identity_1_c (BatchNormal  (None, 4, 4, 512)   2048        ['res_3_identity_1_c[0][0]']
#  ization)
#
#  add_4 (Add)                    (None, 4, 4, 512)    0           ['bn_3_identity_1_c[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 4, 4, 512)    0           ['add_4[0][0]']
#
#  res_3_identity_2_a (Conv2D)    (None, 4, 4, 128)    65664       ['activation_15[0][0]']
#
#  bn_3_identity_2_a (BatchNormal  (None, 4, 4, 128)   512         ['res_3_identity_2_a[0][0]']
#  ization)
#
#  activation_16 (Activation)     (None, 4, 4, 128)    0           ['bn_3_identity_2_a[0][0]']
#
#  res_3_identity_2_b (Conv2D)    (None, 4, 4, 128)    147584      ['activation_16[0][0]']
#
#  bn_3_identity_2_b (BatchNormal  (None, 4, 4, 128)   512         ['res_3_identity_2_b[0][0]']
#  ization)
#
#  activation_17 (Activation)     (None, 4, 4, 128)    0           ['bn_3_identity_2_b[0][0]']
#
#  res_3_identity_2_c (Conv2D)    (None, 4, 4, 512)    66048       ['activation_17[0][0]']
#
#  bn_3_identity_2_c (BatchNormal  (None, 4, 4, 512)   2048        ['res_3_identity_2_c[0][0]']
#  ization)
#
#  add_5 (Add)                    (None, 4, 4, 512)    0           ['bn_3_identity_2_c[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 4, 4, 512)    0           ['add_5[0][0]']
#
#  res_4_conv_a (Conv2D)          (None, 4, 4, 256)    131328      ['activation_18[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 2, 2, 256)   0           ['res_4_conv_a[0][0]']
#
#  bn_4_conv_a (BatchNormalizatio  (None, 2, 2, 256)   1024        ['max_pooling2d_5[0][0]']
#  n)
#
#  activation_19 (Activation)     (None, 2, 2, 256)    0           ['bn_4_conv_a[0][0]']
#
#  res_4_conv_b (Conv2D)          (None, 2, 2, 256)    590080      ['activation_19[0][0]']
#
#  bn_4_conv_b (BatchNormalizatio  (None, 2, 2, 256)   1024        ['res_4_conv_b[0][0]']
#  n)
#
#  activation_20 (Activation)     (None, 2, 2, 256)    0           ['bn_4_conv_b[0][0]']
#
#  res_4_conv_copy (Conv2D)       (None, 4, 4, 1024)   525312      ['activation_18[0][0]']
#
#  res_4_conv_c (Conv2D)          (None, 2, 2, 1024)   263168      ['activation_20[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 2, 2, 1024)  0           ['res_4_conv_copy[0][0]']
#
#  bn_4_conv_c (BatchNormalizatio  (None, 2, 2, 1024)  4096        ['res_4_conv_c[0][0]']
#  n)
#
#  bn_4_conv_copy (BatchNormaliza  (None, 2, 2, 1024)  4096        ['max_pooling2d_6[0][0]']
#  tion)
#
#  add_6 (Add)                    (None, 2, 2, 1024)   0           ['bn_4_conv_c[0][0]',
#                                                                   'bn_4_conv_copy[0][0]']
#
#  activation_21 (Activation)     (None, 2, 2, 1024)   0           ['add_6[0][0]']
#
#  res_4_identity_1_a (Conv2D)    (None, 2, 2, 256)    262400      ['activation_21[0][0]']
#
#  bn_4_identity_1_a (BatchNormal  (None, 2, 2, 256)   1024        ['res_4_identity_1_a[0][0]']
#  ization)
#
#  activation_22 (Activation)     (None, 2, 2, 256)    0           ['bn_4_identity_1_a[0][0]']
#
#  res_4_identity_1_b (Conv2D)    (None, 2, 2, 256)    590080      ['activation_22[0][0]']
#
#  bn_4_identity_1_b (BatchNormal  (None, 2, 2, 256)   1024        ['res_4_identity_1_b[0][0]']
#  ization)
#
#  activation_23 (Activation)     (None, 2, 2, 256)    0           ['bn_4_identity_1_b[0][0]']
#
#  res_4_identity_1_c (Conv2D)    (None, 2, 2, 1024)   263168      ['activation_23[0][0]']
#
#  bn_4_identity_1_c (BatchNormal  (None, 2, 2, 1024)  4096        ['res_4_identity_1_c[0][0]']
#  ization)
#
#  add_7 (Add)                    (None, 2, 2, 1024)   0           ['bn_4_identity_1_c[0][0]',
#                                                                   'activation_21[0][0]']
#
#  activation_24 (Activation)     (None, 2, 2, 1024)   0           ['add_7[0][0]']
#
#  res_4_identity_2_a (Conv2D)    (None, 2, 2, 256)    262400      ['activation_24[0][0]']
#
#  bn_4_identity_2_a (BatchNormal  (None, 2, 2, 256)   1024        ['res_4_identity_2_a[0][0]']
#  ization)
#
#  activation_25 (Activation)     (None, 2, 2, 256)    0           ['bn_4_identity_2_a[0][0]']
#
#  res_4_identity_2_b (Conv2D)    (None, 2, 2, 256)    590080      ['activation_25[0][0]']
#
#  bn_4_identity_2_b (BatchNormal  (None, 2, 2, 256)   1024        ['res_4_identity_2_b[0][0]']
#  ization)
#
#  activation_26 (Activation)     (None, 2, 2, 256)    0           ['bn_4_identity_2_b[0][0]']
#
#  res_4_identity_2_c (Conv2D)    (None, 2, 2, 1024)   263168      ['activation_26[0][0]']
#
#  bn_4_identity_2_c (BatchNormal  (None, 2, 2, 1024)  4096        ['res_4_identity_2_c[0][0]']
#  ization)
#
#  add_8 (Add)                    (None, 2, 2, 1024)   0           ['bn_4_identity_2_c[0][0]',
#                                                                   'activation_24[0][0]']
#
#  activation_27 (Activation)     (None, 2, 2, 1024)   0           ['add_8[0][0]']
#
#  res_5_conv_a (Conv2D)          (None, 2, 2, 512)    524800      ['activation_27[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 1, 1, 512)   0           ['res_5_conv_a[0][0]']
#
#  bn_5_conv_a (BatchNormalizatio  (None, 1, 1, 512)   2048        ['max_pooling2d_7[0][0]']
#  n)
#
#  activation_28 (Activation)     (None, 1, 1, 512)    0           ['bn_5_conv_a[0][0]']
#
#  res_5_conv_b (Conv2D)          (None, 1, 1, 512)    2359808     ['activation_28[0][0]']
#
#  bn_5_conv_b (BatchNormalizatio  (None, 1, 1, 512)   2048        ['res_5_conv_b[0][0]']
#  n)
#
#  activation_29 (Activation)     (None, 1, 1, 512)    0           ['bn_5_conv_b[0][0]']
#
#  res_5_conv_copy (Conv2D)       (None, 2, 2, 2048)   2099200     ['activation_27[0][0]']
#
#  res_5_conv_c (Conv2D)          (None, 1, 1, 2048)   1050624     ['activation_29[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 1, 1, 2048)  0           ['res_5_conv_copy[0][0]']
#
#  bn_5_conv_c (BatchNormalizatio  (None, 1, 1, 2048)  8192        ['res_5_conv_c[0][0]']
#  n)
#
#  bn_5_conv_copy (BatchNormaliza  (None, 1, 1, 2048)  8192        ['max_pooling2d_8[0][0]']
#  tion)
#
#  add_9 (Add)                    (None, 1, 1, 2048)   0           ['bn_5_conv_c[0][0]',
#                                                                   'bn_5_conv_copy[0][0]']
#
#  activation_30 (Activation)     (None, 1, 1, 2048)   0           ['add_9[0][0]']
#
#  res_5_identity_1_a (Conv2D)    (None, 1, 1, 512)    1049088     ['activation_30[0][0]']
#
#  bn_5_identity_1_a (BatchNormal  (None, 1, 1, 512)   2048        ['res_5_identity_1_a[0][0]']
#  ization)
#
#  activation_31 (Activation)     (None, 1, 1, 512)    0           ['bn_5_identity_1_a[0][0]']
#
#  res_5_identity_1_b (Conv2D)    (None, 1, 1, 512)    2359808     ['activation_31[0][0]']
#
#  bn_5_identity_1_b (BatchNormal  (None, 1, 1, 512)   2048        ['res_5_identity_1_b[0][0]']
#  ization)
#
#  activation_32 (Activation)     (None, 1, 1, 512)    0           ['bn_5_identity_1_b[0][0]']
#
#  res_5_identity_1_c (Conv2D)    (None, 1, 1, 2048)   1050624     ['activation_32[0][0]']
#
#  bn_5_identity_1_c (BatchNormal  (None, 1, 1, 2048)  8192        ['res_5_identity_1_c[0][0]']
#  ization)
#
#  add_10 (Add)                   (None, 1, 1, 2048)   0           ['bn_5_identity_1_c[0][0]',
#                                                                   'activation_30[0][0]']
#
#  activation_33 (Activation)     (None, 1, 1, 2048)   0           ['add_10[0][0]']
#
#  res_5_identity_2_a (Conv2D)    (None, 1, 1, 512)    1049088     ['activation_33[0][0]']
#
#  bn_5_identity_2_a (BatchNormal  (None, 1, 1, 512)   2048        ['res_5_identity_2_a[0][0]']
#  ization)
#
#  activation_34 (Activation)     (None, 1, 1, 512)    0           ['bn_5_identity_2_a[0][0]']
#
#  res_5_identity_2_b (Conv2D)    (None, 1, 1, 512)    2359808     ['activation_34[0][0]']
#
#  bn_5_identity_2_b (BatchNormal  (None, 1, 1, 512)   2048        ['res_5_identity_2_b[0][0]']
#  ization)
#
#  activation_35 (Activation)     (None, 1, 1, 512)    0           ['bn_5_identity_2_b[0][0]']
#
#  res_5_identity_2_c (Conv2D)    (None, 1, 1, 2048)   1050624     ['activation_35[0][0]']
#
#  bn_5_identity_2_c (BatchNormal  (None, 1, 1, 2048)  8192        ['res_5_identity_2_c[0][0]']
#  ization)
#
#  add_11 (Add)                   (None, 1, 1, 2048)   0           ['bn_5_identity_2_c[0][0]',
#                                                                   'activation_33[0][0]']
#
#  activation_36 (Activation)     (None, 1, 1, 2048)   0           ['add_11[0][0]']
#
#  Averagea_Pooling (AveragePooli  (None, 1, 1, 2048)  0           ['activation_36[0][0]']
#  ng2D)
#
#  flatten (Flatten)              (None, 2048)         0           ['Averagea_Pooling[0][0]']
#
#  dense (Dense)                  (None, 4096)         8392704     ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 4096)         0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 2048)         8390656     ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 2048)         0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 29)           59421       ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 36,782,749
# Trainable params: 36,740,381
# Non-trainable params: 42,368
# __________________________________________________________________________________________________

# %%
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

# %%
adam = tf.keras.optimizers.Adam(learning_rate = 0.0001, beta_1 = 0.9, beta_2 = 0.999, amsgrad = False)
my_model.compile(loss = "categorical_crossentropy", optimizer = adam , metrics = ['accuracy'])

# %%
lr_scheduler = LearningRateScheduler(scheduler)
earlystopping = EarlyStopping(monitor = 'val_loss', verbose = 1, patience = 5, restore_best_weights=True)

# %%
history = my_model.fit(train_gen, validation_data=val_gen, batch_size = 32,
                       epochs = 20, callbacks=[earlystopping, lr_scheduler])
# Out:
# Epoch 1/20
# 1102/1102 [==============================] - 121s 100ms/step - loss: 1.6978 - accuracy: 0.4749 - val_loss: 0.5815 - val_accuracy: 0.7978 - lr: 1.0000e-04
# Epoch 2/20
# 1102/1102 [==============================] - 80s 73ms/step - loss: 0.4314 - accuracy: 0.8520 - val_loss: 0.2433 - val_accuracy: 0.9156 - lr: 1.0000e-04
# Epoch 3/20
# 1102/1102 [==============================] - 81s 73ms/step - loss: 0.2293 - accuracy: 0.9232 - val_loss: 0.4606 - val_accuracy: 0.8678 - lr: 1.0000e-04
# Epoch 4/20
# 1102/1102 [==============================] - 81s 73ms/step - loss: 0.1714 - accuracy: 0.9444 - val_loss: 0.0771 - val_accuracy: 0.9739 - lr: 1.0000e-04
# Epoch 5/20
# 1102/1102 [==============================] - 80s 73ms/step - loss: 0.1047 - accuracy: 0.9666 - val_loss: 0.0591 - val_accuracy: 0.9805 - lr: 1.0000e-04
# Epoch 6/20
# 1102/1102 [==============================] - 81s 74ms/step - loss: 0.0896 - accuracy: 0.9728 - val_loss: 0.0985 - val_accuracy: 0.9716 - lr: 1.0000e-04
# Epoch 7/20
# 1102/1102 [==============================] - 81s 73ms/step - loss: 0.0862 - accuracy: 0.9737 - val_loss: 0.0695 - val_accuracy: 0.9811 - lr: 1.0000e-04
# Epoch 8/20
# 1102/1102 [==============================] - 80s 73ms/step - loss: 0.0707 - accuracy: 0.9788 - val_loss: 0.0383 - val_accuracy: 0.9884 - lr: 1.0000e-04
# Epoch 9/20
# 1102/1102 [==============================] - 81s 73ms/step - loss: 0.0556 - accuracy: 0.9835 - val_loss: 0.0402 - val_accuracy: 0.9871 - lr: 1.0000e-04
# Epoch 10/20
# 1102/1102 [==============================] - 80s 73ms/step - loss: 0.0498 - accuracy: 0.9856 - val_loss: 0.0128 - val_accuracy: 0.9964 - lr: 1.0000e-04
# Epoch 11/20
# 1102/1102 [==============================] - 80s 73ms/step - loss: 0.0375 - accuracy: 0.9894 - val_loss: 0.0415 - val_accuracy: 0.9867 - lr: 9.0484e-05
# Epoch 12/20
# 1102/1102 [==============================] - 80s 73ms/step - loss: 0.0259 - accuracy: 0.9923 - val_loss: 0.0176 - val_accuracy: 0.9939 - lr: 8.1873e-05
# Epoch 13/20
# 1102/1102 [==============================] - 80s 73ms/step - loss: 0.0224 - accuracy: 0.9940 - val_loss: 0.0385 - val_accuracy: 0.9905 - lr: 7.4082e-05
# Epoch 14/20
# 1102/1102 [==============================] - 80s 73ms/step - loss: 0.0181 - accuracy: 0.9951 - val_loss: 0.0029 - val_accuracy: 0.9992 - lr: 6.7032e-05
# Epoch 15/20
# 1102/1102 [==============================] - 80s 73ms/step - loss: 0.0156 - accuracy: 0.9959 - val_loss: 0.0173 - val_accuracy: 0.9948 - lr: 6.0653e-05
# Epoch 16/20
# 1102/1102 [==============================] - 80s 73ms/step - loss: 0.0100 - accuracy: 0.9973 - val_loss: 0.0037 - val_accuracy: 0.9987 - lr: 5.4881e-05
# Epoch 17/20
# 1102/1102 [==============================] - 81s 73ms/step - loss: 0.0103 - accuracy: 0.9972 - val_loss: 0.0065 - val_accuracy: 0.9989 - lr: 4.9659e-05
# Epoch 18/20
# 1102/1102 [==============================] - 81s 73ms/step - loss: 0.0099 - accuracy: 0.9973 - val_loss: 0.0106 - val_accuracy: 0.9982 - lr: 4.4933e-05
# Epoch 19/20
# 1102/1102 [==============================] - 80s 73ms/step - loss: 0.0050 - accuracy: 0.9988 - val_loss: 6.9631e-04 - val_accuracy: 0.9999 - lr: 4.0657e-05
# Epoch 20/20
# 1102/1102 [==============================] - 80s 73ms/step - loss: 0.0054 - accuracy: 0.9985 - val_loss: 0.0062 - val_accuracy: 0.9985 - lr: 3.6788e-05

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train_loss','val_loss'], loc = 'upper right')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train_accuracy','val_accuracy'], loc = 'lower right')
plt.show()

# %%
pred = my_model.predict(test_gen)
pred = np.argmax(pred,axis=1)

# Map the label
labels = (train_gen.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]

# Get the accuracy on the test set
y_test = list(test_df.Label)
acc = accuracy_score(y_test,pred)

print(acc)
# Out:
# 272/272 [==============================] - 14s 47ms/step
# 0.9982758620689656

# %%
fig, axes = plt.subplots(nrows=4, ncols=6, figsize=(20, 12),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(test_df.Filepath.iloc[i]))
    ax.set_title(f"True: {test_df.Label.iloc[i].split('_')[0]}\nPredicted: {pred[i].split('_')[0]}", fontsize = 15)
plt.tight_layout()
plt.show()
